# %%
import pandas as pd

# %%
df = pd.read_excel("https://github.com/wtitze/3E/blob/main/Medals.xlsx?raw=true")
df
# Out:
#     Rank                    Team/NOC  Gold  ...  Bronze  Total  Rank by Total
# 0      1    United States of America    39  ...      33    113              1
# 1      2  People's Republic of China    38  ...      18     88              2
# 2      3                       Japan    27  ...      17     58              5
# 3      4               Great Britain    22  ...      22     65              4
# 4      5                         ROC    20  ...      23     71              3
# ..   ...                         ...   ...  ...     ...    ...            ...
# 88    86                       Ghana     0  ...       1      1             77
# 89    86                     Grenada     0  ...       1      1             77
# 90    86                      Kuwait     0  ...       1      1             77
# 91    86         Republic of Moldova     0  ...       1      1             77
# 92    86        Syrian Arab Republic     0  ...       1      1             77
#
# [93 rows x 7 columns]

# %% [markdown]
# eliminare la colonna rank , total, rank by total

# %%
df.drop(columns=["Total"])
# Out:
#     Rank                    Team/NOC  Gold  Silver  Bronze  Rank by Total
# 0      1    United States of America    39      41      33              1
# 1      2  People's Republic of China    38      32      18              2
# 2      3                       Japan    27      14      17              5
# 3      4               Great Britain    22      21      22              4
# 4      5                         ROC    20      28      23              3
# ..   ...                         ...   ...     ...     ...            ...
# 88    86                       Ghana     0       0       1             77
# 89    86                     Grenada     0       0       1             77
# 90    86                      Kuwait     0       0       1             77
# 91    86         Republic of Moldova     0       0       1             77
# 92    86        Syrian Arab Republic     0       0       1             77
#
# [93 rows x 6 columns]

# %% [markdown]
# cambiare il nome di Team/NOC , con Team

# %%
df.rename(columns={'Team/NOC' : 'Team'},inplace=True)
df
# Out:
#     Rank                        Team  Gold  ...  Bronze  Total  Rank by Total
# 0      1    United States of America    39  ...      33    113              1
# 1      2  People's Republic of China    38  ...      18     88              2
# 2      3                       Japan    27  ...      17     58              5
# 3      4               Great Britain    22  ...      22     65              4
# 4      5                         ROC    20  ...      23     71              3
# ..   ...                         ...   ...  ...     ...    ...            ...
# 88    86                       Ghana     0  ...       1      1             77
# 89    86                     Grenada     0  ...       1      1             77
# 90    86                      Kuwait     0  ...       1      1             77
# 91    86         Republic of Moldova     0  ...       1      1             77
# 92    86        Syrian Arab Republic     0  ...       1      1             77
#
# [93 rows x 7 columns]

# %% [markdown]
# creare una nuova colonna per calcolare il totale delle nazioni

# %%
df["Total"]=df["Gold"]+df["Silver"]+df["Bronze"]
df
# Out:
#     Rank                        Team  Gold  ...  Bronze  Total  Rank by Total
# 0      1    United States of America    39  ...      33    113              1
# 1      2  People's Republic of China    38  ...      18     88              2
# 2      3                       Japan    27  ...      17     58              5
# 3      4               Great Britain    22  ...      22     65              4
# 4      5                         ROC    20  ...      23     71              3
# ..   ...                         ...   ...  ...     ...    ...            ...
# 88    86                       Ghana     0  ...       1      1             77
# 89    86                     Grenada     0  ...       1      1             77
# 90    86                      Kuwait     0  ...       1      1             77
# 91    86         Republic of Moldova     0  ...       1      1             77
# 92    86        Syrian Arab Republic     0  ...       1      1             77
#
# [93 rows x 7 columns]

# %% [markdown]
# nazioni con più di 80 medaglie in totale

# %%
df[df["Total"]>80][["Team"]]
# Out:
#                          Team
# 0    United States of America
# 1  People's Republic of China

# %% [markdown]
# numero medio di medaglie vinte dalle nazioni

# %%
df["Total"].mean()
# Out:
# 11.612903225806452

# %% [markdown]
# quali sono le nazioni che hanno vinto più medaglie della media

# %%
df[df["Total"]>df["Total"].mean()]
# Out:
#     Rank                        Team  Gold  ...  Bronze  Total  Rank by Total
# 0      1    United States of America    39  ...      33    113              1
# 1      2  People's Republic of China    38  ...      18     88              2
# 2      3                       Japan    27  ...      17     58              5
# 3      4               Great Britain    22  ...      22     65              4
# 4      5                         ROC    20  ...      23     71              3
# 5      6                   Australia    17  ...      22     46              6
# 6      7                 Netherlands    10  ...      14     36              9
# 7      8                      France    10  ...      11     33             10
# 8      9                     Germany    10  ...      16     37              8
# 9     10                       Italy    10  ...      20     40              7
# 10    11                      Canada     7  ...      11     24             11
# ...

# %%
df1=pd.read_excel("https://github.com/wtitze/3E/blob/main/Athletes.xlsx?raw=true")
df1
# Out:
#                         Name      NOC           Discipline
# 0            AALERUD Katrine   Norway         Cycling Road
# 1                ABAD Nestor    Spain  Artistic Gymnastics
# 2          ABAGNALE Giovanni    Italy               Rowing
# 3             ABALDE Alberto    Spain           Basketball
# 4              ABALDE Tamara    Spain           Basketball
# ...                      ...      ...                  ...
# 11080  ZWICKER Martin Detlef  Germany               Hockey
# 11081      ZWOLINSKA Klaudia   Poland         Canoe Slalom
# 11082           ZYKOVA Yulia      ROC             Shooting
# 11083      ZYUZINA Ekaterina      ROC              Sailing
# 11084        ZYZANSKA Sylwia   Poland              Archery
#
# [11085 rows x 3 columns]

# %% [markdown]
# numero di atleti x ogni nazione

# %%
df1.groupby("NOC").count()
# Out:
#                          Name  Discipline
# NOC
# Afghanistan                 5           5
# Albania                     8           8
# Algeria                    41          41
# American Samoa              5           5
# Andorra                     2           2
# ...                       ...         ...
# Virgin Islands, British     3           3
# Virgin Islands, US          4           4
# Yemen                       3           3
# Zambia                     29          29
# Zimbabwe                    5           5
#
# [206 rows x 2 columns]

# %% [markdown]
# quanti atleti in italia

# %%
df1[df1["NOC"].str.contains("Italy")].count()
# Out:
# Name          356
# NOC           356
# Discipline    356
# dtype: int64

# %% [markdown]
# nazioni che hanno più di 300 atleti

# %%
df2=df1.groupby("NOC").count()
df2[df2["Discipline"]>300]
# Out:
#                             Name  Discipline
# NOC
# Australia                    470         470
# Canada                       368         368
# France                       377         377
# Germany                      400         400
# Great Britain                366         366
# Italy                        356         356
# Japan                        586         586
# People's Republic of China   401         401
# ROC                          318         318
# Spain                        324         324
# United States of America     615         615

# %% [markdown]
# nazione che ha portato più atleti

# %%
df2[df2["Name"]==df2["Name"].max()]
# Out:
#                           Name  Discipline
# NOC
# United States of America   615         615

# %% [markdown]
# il numero di nazioni per ogni disciplina

# %%
df1.groupby("Discipline").count()
# Out:
#                        Name   NOC
# Discipline
# 3x3 Basketball           62    62
# Archery                 122   122
# Artistic Gymnastics     187   187
# Artistic Swimming        98    98
# Athletics              2068  2068
# Badminton               164   164
# Baseball/Softball       220   220
# Basketball              280   280
# Beach Volleyball         90    90
# Boxing                  270   270
# Canoe Slalom             78    78
# Canoe Sprint            236   236
# Cycling BMX Freestyle    19    19
# Cycling BMX Racing       43    43
# Cycling Mountain Bike    74    74
# Cycling Road            190   190
# Cycling Track           208   208
# Diving                  133   133
# Equestrian              237   237
# Fencing                 249   249
# Football                567   567
# Golf                    115   115
# Handball                343   343
# Hockey                  406   406
# Judo                    373   373
# Karate                   77    77
# ...

# %% [markdown]
# disciplina con meno squadre
